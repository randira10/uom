# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.0 MB 1.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.3/11.0 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.0 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.0 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/11.0 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.0 MB 1.4 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/11.0 MB 1.4 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
num_cols = [col for col in df.columns if df[col].dtype != 'object']

print("Categorical Columns:", cat_cols)
print("Numerical Columns:", num_cols)
# Out:
# Categorical Columns: []
# Numerical Columns: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
df[num_cols].nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
df_processed = df.drop(columns=['Age', 'Outcome', 'BMI','DiabetesPedigreeFunction'])
df_processed.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    768 non-null    int64
#  1   Glucose        768 non-null    int64
#  2   BloodPressure  768 non-null    int64
#  3   SkinThickness  768 non-null    int64
#  4   Insulin        768 non-null    int64
# dtypes: int64(5)
# memory usage: 30.1 KB

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/8.1 MB 3.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/8.1 MB 2.1 MB/s eta 0:00:04
# ...

# %%
import matplotlib.pyplot as plt

plt.boxplot(df_processed['Glucose'], vert=False)
plt.title('Box plot of Glucose')
plt.xlabel('Glucose Levels')
plt.show()

plt.boxplot(df_processed['Pregnancies'], vert=False)
plt.title('Box plot of Pregnancies')
plt.xlabel('Pregnancies Levels')
plt.show()

plt.boxplot(df_processed['BloodPressure'], vert=False)
plt.title('Box plot of BloodPressure')
plt.xlabel('BloodPressure Levels')
plt.show()

plt.boxplot(df_processed['SkinThickness'], vert=False)
plt.title('Box plot of SkinThickness')
plt.xlabel('SkinThickness Levels')
plt.show()

# %%
mean_glucose = df_processed['Pregnancies'].mean()
std_glucose = df_processed['Pregnancies'].std()

lower_bound = mean_glucose - 2 * std_glucose
upper_bound = mean_glucose + 2 * std_glucose

outliers = df_processed[(df_processed['Pregnancies'] < lower_bound) | (df_processed['Pregnancies'] > upper_bound)]

# %%
outliers.shape
# Out:
# (34, 5)

# %%
df_processed = df_processed[(df_processed['Pregnancies'] >= lower_bound) & (df_processed['Pregnancies'] <= upper_bound)]

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 767
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    734 non-null    int64
#  1   Glucose        734 non-null    int64
#  2   BloodPressure  734 non-null    int64
#  3   SkinThickness  734 non-null    int64
#  4   Insulin        734 non-null    int64
# dtypes: int64(5)
# memory usage: 34.4 KB

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import numpy as np
q1, q3 = np.percentile(df['Pregnancies'], [25, 75])
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
cleaned_df = df[(df['Pregnancies'] >= lower_bound) & (df['Pregnancies'] <= upper_bound)]
cleaned_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   764.000000  764.000000     764.000000     764.000000  764.000000
# mean      3.786649  120.776178      69.098168      20.476440   79.683246
# std       3.278714   31.946234      19.401789      15.966814  115.436078
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   27.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.250000
# max      13.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  764.000000                764.000000  764.000000  764.000000
# mean    31.966099                  0.472260   33.187173    0.345550
# std      7.894034                  0.331619   11.764745    0.475859
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
corr = cleaned_df.corr()
import seaborn as sns

plt.figure(figsize=(10, 8), dpi=96)
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
print(corr['BMI'].sort_values(ascending=False))
# Out:
# BMI                         1.000000
# SkinThickness               0.390889
# Outcome                     0.289917
# BloodPressure               0.281744
# Glucose                     0.219821
# Insulin                     0.197148
# DiabetesPedigreeFunction    0.140711
# Age                         0.032986
# Pregnancies                 0.006171
# Name: BMI, dtype: float64

# %%
plt.pie(cleaned_df['Outcome'].value_counts(), labels=['Diabetes', 'No Diabetes'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Diabetes Outcome')
plt.show()

# %%
X = cleaned_df.drop(columns=['Outcome'])
y = cleaned_df['Outcome']

# %%
scaler = MinMaxScaler()
X_normalized = X.copy()
X_normalized = scaler.fit_transform(X)
X_normalized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 scaler = MinMaxScaler()
#       2 X_normalized = X.copy()
#       3 X_normalized = scaler.fit_transform(X)
#
# NameError: name 'MinMaxScaler' is not defined
